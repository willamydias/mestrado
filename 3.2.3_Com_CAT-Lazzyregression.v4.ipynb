# %% [markdown]
# # incializando ambiente

# %%
# %%time
import os
os.environ['USE_PYGEOS'] = '0'
import plotly.express as px
import IPython
from IPython.display import display, HTML

import locale

# Definir o ponto como separador de números
#locale.setlocale(locale.LC_NUMERIC, 'en_US.UTF-8')
locale.setlocale(locale.LC_ALL, "Portuguese_Brazil.1252")
# Definir o locale para o formato brasileiro (pt_BR)

# Função para formatar os números com ponto como separador de milhar e vírgula como separador decimal
def formatar_numero(valor):
    return '{:,.3f}'.format(valor)

# Registrar a função de formatação para uso global em saídas
display(HTML('<style>.output {font-size: 14px;}</style>'))  # Apenas para ajustar o tamanho da fonte
display(HTML('<script>var formatarNumero = {};</script>'.format(formatar_numero)))


import scipy as sp
#import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 5)
plt.rcParams['axes.formatter.use_locale'] = True

import warnings
import re
warnings.filterwarnings('ignore')
pd.set_option("display.precision", 3)
pd.set_option("display.float_format", '{:,.3f}'.format) 
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 50)
pd.options.display.min_rows = 115
label = 'valor_oferta'

from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.base import RegressorMixin
from sklearn.utils import (shuffle,
                           all_estimators)

from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.experimental import (enable_hist_gradient_boosting,
                                  enable_halving_search_cv )

from sklearn.model_selection import (HalvingRandomSearchCV, 
                                     cross_val_score, 
                                     cross_val_predict,
                                     RandomizedSearchCV,
                                     cross_validate,
                                     train_test_split,
                                     GridSearchCV)

from sklearn.metrics import (RocCurveDisplay, 
                             r2_score,
                             mean_absolute_error, 
                             mean_squared_error,
                             PredictionErrorDisplay,
                             explained_variance_score)

from sklearn.compose import make_column_transformer, make_column_selector, ColumnTransformer
from sklearn.pipeline import make_pipeline

import xgboost
import lightgbm

from sklearn.preprocessing import (LabelEncoder, 
                                   OrdinalEncoder,
                                   OneHotEncoder, 
                                   MinMaxScaler,
                                   minmax_scale,
                                   MaxAbsScaler,
                                   StandardScaler,
                                   RobustScaler,
                                   Normalizer,
                                   QuantileTransformer,
                                   PowerTransformer)
# %matplotlib inline
import statsmodels.api as sm

from yellowbrick.features import FeatureImportances, JointPlotVisualizer
from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC
from yellowbrick.regressor import AlphaSelection, CooksDistance, ManualAlphaSelection, ResidualsPlot, PredictionError
from yellowbrick.datasets import load_concrete


# %autosave 120
# Out:
# <style>.output {font-size: 14px;}</style>
# <script>var formatarNumero = <function formatar_numero at 0x000001E5B72A31C0>;</script>
# Autosaving every 120 seconds
# CPU times: total: 3.5 s
# Wall time: 11.5 s

# %% [markdown]
# ## Carregando banco de dados

# %%
# %%time
# import data
df = pd.read_csv('gdf_final - gdf_final_ultimo.csv',  # gdf_clean_1_4_2023.csv  gdf_final.csv
                encoding = 'ANSI', sep=';' , decimal=',' ) #'utf-8'

#############
#df['R$_por_m2'] = df ['valor_oferta'] / df ['area'] / R$_por_m2
#df_sem_duplicatas = df.drop_duplicates(subset=['valor_ponderado', 'area',
                                               #'ra','setor', 'data_condicao', 'vend_data_data'])

df['valor_oferta'] = df['valor_ponderado']

del df['R$_por_m2'] , df['data_condicao'] , df['valor_ponderado'] , df['area_acumulada'], df['setor_distancia']

# alta correlação <----------------------------------------------------------------------
del df['valor_taxa_impermeabilidade'] , df['distancia_de_400_metros_maisperto'] , df['mobiliario_esporte_e_lazer_contagem'] 

#del df['index_atualizacao'] 
#df['valor_oferta'].describe()
# df['valor_ponderado'].describe()

cat_cols = df.select_dtypes(include=['category', 'string', 'object']).columns.to_list()

cat_cols_num = []
# Loop para iterar sobre as colunas do DataFrame
for coluna in df.select_dtypes(exclude=['category', 'string', 'object']).columns:
    # Verificar se a coluna possui menos de 20 valores únicos
    if df[coluna].nunique() < 30:
        # Transformar a coluna em tipo categórico
        #print(coluna, df[coluna].nunique())
        df[coluna] = df[coluna].astype('category')
        cat_cols.append(coluna)
        cat_cols_num.append(coluna)
# Out:
# CPU times: total: 156 ms
# Wall time: 285 ms

# %% [markdown]
# ### dados categoricos

# %%
# %%time
for cols in cat_cols:
    print(cols, len(df[cols].unique()))
# Out:
# ra 19
# setor 164
# situacao 8
# tipologia 40
# destinacao 192
# index_atualizacao 237
# vendido_em_grupo 2
# ref_referencia 3
# pos_posicao 3
# linhas_de_transportes_de_alta_densidade_contagem 13
# mapa_1c_unidades_de_planejamento_territorial_contagem 4
# mapa_1c_unidades_de_planejamento_territorial_maisperto 6
# area_tombada_contagem 2
# regioes_administrativas_maisperto 23
# rede_estrutural_de_transporte_coletivo_contagem 20
# regulaziracao_contagem 5
# diretrizes_urbanisticas_contagem 7
# CPU times: total: 31.2 ms
# Wall time: 16 ms

# %% [markdown]
# Apresentado dados davariável

# %%
#import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# Função para formatar os números em milhares com o sufixo 'k'
def formatar_milhares(x, pos):
    if x >= 1000000:
        return f'{x/1000000:.0f} Mi'
    return f'{x/1000:.0f} K'

# Definir a função de formatação para o eixo y
#formatter = mticker.FuncFormatter(formatar_milhares)
#plt.gca().xaxis.set_major_formatter(formatter)
plt.figure(figsize=(10, 5)) 
# Criar o histograma
n, bins, patches = plt.hist(df['valor_oferta'], bins=500, edgecolor='black')  # O número de bins pode ser ajustado conforme necessário
#plt.hist(df['valor_oferta'],  bins=1000,edgecolor='black')  # bins=50, O número de bins pode ser ajustado conforme necessário

plt.xlim(df['valor_oferta'].min(), df['valor_oferta'].max())

# Adicionar rótulos e título
plt.xlabel('Valor da Oferta (R$)')
plt.ylabel('Frequência (Observações)')
plt.title('Histograma da Variável Dependente (valor_oferta)')

# Definir o eixo x em escala logarítmica
plt.yscale('linear')
plt.xscale('log')

# Definir os rótulos do eixo x em potências de 10 (ou outros valores desejados)
potencias = [100, 500, 2500, 5000, 7500]  # Exemplo de potências de 10 como rótulos do eixo x
plt.yticks(potencias, [f'{p}' for p in potencias])

# Definir os rótulos do eixo x em potências de 10 (ou outros valores desejados)
potencias = [ df['valor_oferta'].min()-1, 100000, 1000000, 10000000,  df['valor_oferta'].max()+1]  # Exemplo de potências de 10 como rótulos do eixo x
plt.xticks(potencias , [f'{formatar_milhares(int(p),1)}' for p in potencias]) #[f'1{int(np.log10(p))}' for p in potencias]

# Adicionar a contagem dos valores no gráfico
#for count, x, patch in zip(n, bins[:-1], patches):
#    height = patch.get_height()
#    plt.text(x + (bins[1] - bins[0]) / 2, height, f'{int(count)}', ha='center', va='bottom')
    
    
# Exibir o gráfico
plt.show()

# %%
df['valor_oferta'].describe()
# Out:
# count        9959.00
# mean       916170.68
# std       3237944.42
# min          3375.00
# 25%         79601.00
# 50%        176670.00
# 75%        405058.50
# max     129670000.00
# Name: valor_oferta, dtype: float64

# %% [markdown]
# ## Dividindo dataframe
# (Variáveis independentes X e dependentes Y)

# %%
# %%time
X = df.drop("valor_oferta", axis=1)

X_trans = df.drop("valor_oferta", axis=1)


#
### transformações em Y
#

y_1 = df["valor_oferta"]
y_2 = df["valor_oferta"] / df["area"]
y_3 = np.log(df["valor_oferta"] / df["area"])
y_4 = np.log(df["valor_oferta"])
y_5 = 1 / np.sqrt(df["valor_oferta"])


#X = X.drop(cat_cols, axis=1)
#X.columns

#
# transformações em X
#
def custom_transformation(valor_original):
    transformed_valor_original= 1 / (valor_original ** 2)
    return transformed_valor_original

X_trans['area'] = np.log(X_trans['area'])
#X_trans['tipologia'] = np.log(X_trans['tipologia'])


y_1.name = "Valor_Oferta"
y_2.name = "Valor_Oferta/area"
y_3.name = "log(Valor_Oferta/area)"
y_4.name = "log(Valor_Oferta)"
y_5.name = "1/Valor_Oferta¹/²"
# Out:
# CPU times: total: 15.6 ms
# Wall time: 8 ms

# %%
sns.boxenplot(x=y_4, y=df['ra'], k_depth="trustworthy", 
              scale="exponential")
# Out:
# <Axes: xlabel='log(Valor_Oferta)', ylabel='ra'>

# %% [markdown]
# ### Tratamento

# %%
# %%time
#############################################
# TRATAMENTO DAS VARIÁVEIS CATEGÓRICAS
# ra 19 / setor 199 / condicao 43 / situacao 8 / tipologia 43 / destinacao 287
#############################################
preprocessor  = ColumnTransformer([("cat_",
#         OneHotEncoder(sparse_output=False, handle_unknown="ignore"),
         OrdinalEncoder(dtype=np.int64),
         cat_cols),],).set_output(transform="pandas")

#melhor_regressor_one_hot = make_pipeline(
#    one_hot_encoder, HistGradientBoostingRegressor(**melhor_parametro, random_state=42)
#)

X[cat_cols] = preprocessor.fit_transform(X)
#X[cat_cols]
# Out:
# CPU times: total: 46.9 ms
# Wall time: 48 ms

# %% [markdown]
# ## Selecionando regressores
# utilizando biblioteca lazzyregressor

# %%
# %%time
all_estimators()
removed_regressors = [
    "TheilSenRegressor",
    "ARDRegression", 
    "CCA", 
    "IsotonicRegression", 
    "StackingRegressor",
    "MultiOutputRegressor", 
    "MultiTaskElasticNet", 
    "MultiTaskElasticNetCV", 
    "MultiTaskLasso", 
    "MultiTaskLassoCV", 
    "PLSCanonical", 
    "PLSRegression", 
    "RadiusNeighborsRegressor", 
    "RegressorChain", 
    "VotingRegressor", 
    #adicionado por custo temporal
    "RandomForestRegressor",
    "QuantileRegressor",
]

REGRESSORS = [
    est
    for est in all_estimators()
    if (issubclass(est[1], RegressorMixin) and (est[0] not in removed_regressors))
]

#(n_estimators=1000, learning_rate=0.05, n_jobs=4) 
REGRESSORS.append(("XGBRegressor", xgboost.XGBRegressor))
#(task = 'train',   objective= 'regression', subsample= 0.8, max_depth=7, learning_rate= 0.1)
REGRESSORS.append(("LGBMRegressor", lightgbm.LGBMRegressor ))



#regressors= 
#REGRESSORS
# Out:
# CPU times: total: 141 ms
# Wall time: 141 ms

# %%
# %%time
print(y_1.name)

#X_train, X_test, y_train, y_test = train_test_split(X, y_1, test_size=0.25, random_state=0)
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X, y_1, test_size=0.3, random_state=42)

    
reg_1 = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None, predictions=True , regressors=REGRESSORS)
    
models_1, predictions_1 = reg_1.fit(X_train_1, X_test_1, y_train_1, y_test_1)
    
model_dictionary_1= reg_1.provide_models(X_train_1, X_test_1, y_train_1, y_test_1)


models_1[models_1['R-Squared']>=0.7]

#models[models['R-Squared']>=0.4]
models_1 = models_1.reset_index().rename(columns={'index': 'Index'})
models_1['y']=y_1.name
models_1['frame']='models_1'
# Out:
# Valor_Oferta
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [00:59<00:00,  1.50s/it]
# CPU times: total: 6min 38s
# Wall time: 60 s

# %%
# %%time
print(y_2.name)

#X_train, X_test, y_train, y_test = train_test_split(X, y2, test_size=0.25, random_state=0)
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X, y_2, test_size=0.3, random_state=42)

    
reg_2 = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None, predictions=True , regressors=REGRESSORS)
    
models_2, predictions_2 = reg_2.fit(X_train_2, X_test_2, y_train_2, y_test_2)
    
model_dictionary_2= reg_2.provide_models(X_train_2, X_test_2, y_train_2, y_test_2)

models_2[models_2['R-Squared']>=0.7]

#models[models['R-Squared']>=0.4]
models_2 = models_2.reset_index().rename(columns={'index': 'Index'})
models_2['y']=y_2.name
models_2['frame']='models_2'
# Out:
# Valor_Oferta/area
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [00:57<00:00,  1.43s/it]
# CPU times: total: 6min 32s
# Wall time: 57.4 s

# %%
# %%time
print(y_3.name)

#X_train, X_test, y_train, y_test = train_test_split(X, y3, test_size=0.25, random_state=0)
X_train_3, X_test_3, y_train_3, y_test_3 = train_test_split(X, y_3, test_size=0.3, random_state=42)

    
reg_3 = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None, predictions=True , regressors=REGRESSORS)
    
models_3, predictions_3 = reg_3.fit(X_train_3, X_test_3, y_train_3, y_test_3 )
    
model_dictionary_3= reg_3.provide_models(X_train_3, X_test_3, y_train_3, y_test_3 )

models_3[models_3['R-Squared']>=0.7]

#models[models['R-Squared']>=0.4]
models_3 = models_3.reset_index().rename(columns={'index': 'Index'})
models_3['y']=y_3.name
models_3['frame']='models_3'
# Out:
# log(Valor_Oferta/area)
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [00:57<00:00,  1.43s/it]
# CPU times: total: 6min 37s
# Wall time: 57.3 s

# %%
# %%time
print(y_4.name)

#X_train, X_test, y_train, y_test = train_test_split(X, y3, test_size=0.25, random_state=0)
X_train_4, X_test_4, y_train_4, y_test_4 = train_test_split(X, y_4, test_size=0.3, random_state=42)

    
reg_4 = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None, predictions=True , regressors=REGRESSORS)
    
models_4, predictions_4 = reg_3.fit(X_train_4, X_test_4, y_train_4, y_test_4 )
    
model_dictionary_4= reg_4.provide_models(X_train_4, X_test_4, y_train_4, y_test_4 )

models_4[models_4['R-Squared']>=0.7]

#models[models['R-Squared']>=0.4]
models_4 = models_4.reset_index().rename(columns={'index': 'Index'})
models_4['y']=y_4.name
models_4['frame']='models_4'
# Out:
# log(Valor_Oferta)
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [00:58<00:00,  1.46s/it]
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [00:58<00:00,  1.46s/it]
# CPU times: total: 13min 33s
# Wall time: 1min 56s

# %%
# %%time
print(y_5.name)

#X_train, X_test, y_train, y_test = train_test_split(X, y3, test_size=0.25, random_state=0)
X_train_5, X_test_5, y_train_5, y_test_5 = train_test_split(X, y_5, test_size=0.3, random_state=42)

    
reg_5 = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None, predictions=True , regressors=REGRESSORS)
    
models_5, predictions_5 = reg_3.fit(X_train_5, X_test_5, y_train_5, y_test_5)
    
model_dictionary_5= reg_5.provide_models(X_train_5, X_test_5, y_train_5, y_test_5 )

models_5[models_5['R-Squared']>=0.7]

#models[models['R-Squared']>=0.4]
models_5 = models_5.reset_index().rename(columns={'index': 'Index'})
models_5['y']=y_5.name
models_5['frame']='models_5'
# Out:
# 1/Valor_Oferta¹/²
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [01:06<00:00,  1.66s/it]
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [01:05<00:00,  1.65s/it]
# CPU times: total: 9min 59s
# Wall time: 2min 12s

# %%
models_4
# Out:
#                             Model  Adjusted R-Squared  R-Squared   RMSE  \
# 0                   LGBMRegressor                0.92       0.92   0.39
# 1   HistGradientBoostingRegressor                0.92       0.92   0.40
# 2                    XGBRegressor                0.92       0.92   0.40
# 3             ExtraTreesRegressor                0.91       0.91   0.42
# 4                BaggingRegressor                0.90       0.90   0.45
# 5       GradientBoostingRegressor                0.90       0.90   0.45
# 6                             SVR                0.87       0.87   0.52
# 7                           NuSVR                0.87       0.87   0.52
# 8                    MLPRegressor                0.86       0.86   0.53
# 9           DecisionTreeRegressor                0.83       0.84   0.58
# 10             ExtraTreeRegressor                0.81       0.81   0.61
# 11            KNeighborsRegressor                0.77       0.78   0.67
# 12              AdaBoostRegressor                0.74       0.74   0.72
# 13                    LassoLarsIC                0.63       0.63   0.86
# 14                  BayesianRidge                0.63       0.63   0.86
# 15                        RidgeCV                0.63       0.63   0.86
# 16                          Ridge                0.63       0.63   0.86
# 17     TransformedTargetRegressor                0.63       0.63   0.86
# 18               LinearRegression                0.63       0.63   0.86
# 19                   ElasticNetCV                0.62       0.63   0.87
# 20                        LassoCV                0.62       0.63   0.87
# 21                    LassoLarsCV                0.62       0.63   0.87
# 22                         LarsCV                0.61       0.62   0.88
# 23                           Lars                0.61       0.61   0.89
# 24               PoissonRegressor                0.58       0.59   0.91
# 25    OrthogonalMatchingPursuitCV                0.53       0.53   0.97
# 26               TweedieRegressor                0.52       0.52   0.98
# 27                 GammaRegressor                0.48       0.48   1.02
# 28                 HuberRegressor                0.46       0.46   1.04
# 29                      LinearSVR                0.41       0.41   1.09
# 30      OrthogonalMatchingPursuit                0.40       0.40   1.10
# 31                     ElasticNet                0.09       0.10   1.35
# 32                 DummyRegressor               -0.01      -0.00   1.42
# 33                          Lasso               -0.01      -0.00   1.42
# 34                      LassoLars               -0.01      -0.00   1.42
# 35     PassiveAggressiveRegressor               -0.11      -0.10   1.49
# 36                RANSACRegressor               -0.22      -0.20   1.56
# 37                    KernelRidge              -74.26     -73.37  12.26
# 38       GaussianProcessRegressor             -141.34    -139.67  16.86
# 39                   SGDRegressor          -143406.32 -141725.95 535.29
#
#     Time Taken                  y     frame
# 0         0.36  log(Valor_Oferta)  models_4
# 1         1.46  log(Valor_Oferta)  models_4
# 2         0.60  log(Valor_Oferta)  models_4
# 3        13.26  log(Valor_Oferta)  models_4
# 4         2.51  log(Valor_Oferta)  models_4
# 5         3.30  log(Valor_Oferta)  models_4
# 6         6.54  log(Valor_Oferta)  models_4
# 7         6.00  log(Valor_Oferta)  models_4
# 8         5.55  log(Valor_Oferta)  models_4
# 9         0.36  log(Valor_Oferta)  models_4
# 10        0.16  log(Valor_Oferta)  models_4
# 11        0.07  log(Valor_Oferta)  models_4
# 12        1.34  log(Valor_Oferta)  models_4
# 13        0.05  log(Valor_Oferta)  models_4
# 14        0.03  log(Valor_Oferta)  models_4
# 15        0.04  log(Valor_Oferta)  models_4
# 16        0.03  log(Valor_Oferta)  models_4
# 17        0.03  log(Valor_Oferta)  models_4
# 18        0.03  log(Valor_Oferta)  models_4
# 19        0.27  log(Valor_Oferta)  models_4
# 20        0.26  log(Valor_Oferta)  models_4
# 21        0.12  log(Valor_Oferta)  models_4
# 22        0.12  log(Valor_Oferta)  models_4
# 23        0.04  log(Valor_Oferta)  models_4
# 24        0.06  log(Valor_Oferta)  models_4
# 25        0.06  log(Valor_Oferta)  models_4
# 26        0.04  log(Valor_Oferta)  models_4
# 27        0.05  log(Valor_Oferta)  models_4
# 28        0.18  log(Valor_Oferta)  models_4
# 29        0.47  log(Valor_Oferta)  models_4
# 30        0.03  log(Valor_Oferta)  models_4
# 31        0.03  log(Valor_Oferta)  models_4
# 32        0.02  log(Valor_Oferta)  models_4
# 33        0.03  log(Valor_Oferta)  models_4
# 34        0.03  log(Valor_Oferta)  models_4
# 35        0.04  log(Valor_Oferta)  models_4
# 36        0.26  log(Valor_Oferta)  models_4
# 37        3.03  log(Valor_Oferta)  models_4
# 38       11.31  log(Valor_Oferta)  models_4
# 39        0.04  log(Valor_Oferta)  models_4

# %%
models_all = models_1.merge(models_2, how='outer')
models_all = models_all.merge(models_3, how='outer')
models_all = models_all.merge(models_4, how='outer')
models_all = models_all.merge(models_5, how='outer')

# %%
models_all = models_all.sort_values('R-Squared', ascending=False)
models_all[models_all['R-Squared']>=0.75]
# Out:
#                              Model  Adjusted R-Squared  R-Squared       RMSE  \
# 120                  LGBMRegressor                0.92       0.92       0.39
# 121  HistGradientBoostingRegressor                0.92       0.92       0.40
# 122                   XGBRegressor                0.92       0.92       0.40
# 123            ExtraTreesRegressor                0.91       0.91       0.42
# 124               BaggingRegressor                0.90       0.90       0.45
# 125      GradientBoostingRegressor                0.90       0.90       0.45
# 126                            SVR                0.87       0.87       0.52
# 127                          NuSVR                0.87       0.87       0.52
# 80   HistGradientBoostingRegressor                0.86       0.86       0.39
# 128                   MLPRegressor                0.86       0.86       0.53
# 81                   LGBMRegressor                0.86       0.86       0.40
# 82                    XGBRegressor                0.86       0.86       0.40
# 83             ExtraTreesRegressor                0.84       0.84       0.42
# 160  HistGradientBoostingRegressor                0.84       0.84       0.00
# 161                  LGBMRegressor                0.84       0.84       0.00
# 129          DecisionTreeRegressor                0.83       0.84       0.58
# 84                BaggingRegressor                0.83       0.83       0.43
# 85       GradientBoostingRegressor                0.82       0.82       0.45
# 0                    LGBMRegressor                0.82       0.82 1205027.60
# 162      GradientBoostingRegressor                0.81       0.82       0.00
# 130             ExtraTreeRegressor                0.81       0.81       0.61
# 163                   XGBRegressor                0.81       0.81       0.00
# 86                             SVR                0.81       0.81       0.46
# 87                           NuSVR                0.81       0.81       0.46
# 1                 BaggingRegressor                0.81       0.81 1229181.85
# 164            ExtraTreesRegressor                0.81       0.81       0.00
# 88                    MLPRegressor                0.80       0.81       0.47
# 2    HistGradientBoostingRegressor                0.80       0.80 1254829.47
# 165               BaggingRegressor                0.79       0.80       0.00
# 3              ExtraTreesRegressor                0.79       0.79 1291407.79
# 131            KNeighborsRegressor                0.77       0.78       0.67
# 4        GradientBoostingRegressor                0.76       0.76 1381158.08
#
#      Time Taken                       y     frame
# 120        0.36       log(Valor_Oferta)  models_4
# 121        1.46       log(Valor_Oferta)  models_4
# 122        0.60       log(Valor_Oferta)  models_4
# 123       13.26       log(Valor_Oferta)  models_4
# 124        2.51       log(Valor_Oferta)  models_4
# 125        3.30       log(Valor_Oferta)  models_4
# 126        6.54       log(Valor_Oferta)  models_4
# 127        6.00       log(Valor_Oferta)  models_4
# 80         1.48  log(Valor_Oferta/area)  models_3
# 128        5.55       log(Valor_Oferta)  models_4
# 81         0.36  log(Valor_Oferta/area)  models_3
# 82         0.61  log(Valor_Oferta/area)  models_3
# 83        12.59  log(Valor_Oferta/area)  models_3
# 160        1.47       1/Valor_Oferta¹/²  models_5
# 161        0.35       1/Valor_Oferta¹/²  models_5
# 129        0.36       log(Valor_Oferta)  models_4
# 84         2.47  log(Valor_Oferta/area)  models_3
# 85         3.32  log(Valor_Oferta/area)  models_3
# 0          0.33            Valor_Oferta  models_1
# 162        3.35       1/Valor_Oferta¹/²  models_5
# 130        0.16       log(Valor_Oferta)  models_4
# 163        0.29       1/Valor_Oferta¹/²  models_5
# 86         6.16  log(Valor_Oferta/area)  models_3
# 87         6.16  log(Valor_Oferta/area)  models_3
# 1          2.77            Valor_Oferta  models_1
# 164       13.23       1/Valor_Oferta¹/²  models_5
# 88         5.40  log(Valor_Oferta/area)  models_3
# 2          1.29            Valor_Oferta  models_1
# 165        2.51       1/Valor_Oferta¹/²  models_5
# 3         14.04            Valor_Oferta  models_1
# 131        0.07       log(Valor_Oferta)  models_4
# 4          3.28            Valor_Oferta  models_1

# %%
#models_all[models_all['frame']=='models_1'].head(1)
# Use a função groupby para agrupar os dados pela coluna YY e em seguida, use a função idxmax() para encontrar o índice do maior valor de XX para cada categoria de YY
idx = models_all.groupby('frame')['Adjusted R-Squared'].idxmax()

# Use a função loc() para acessar o valor correspondente na coluna BB
max_modelos = models_all.loc[idx, ['Model', 'frame', 'Adjusted R-Squared']]

max_mod_1 = max_modelos.iloc[0]['Model']
max_mod_2 = max_modelos.iloc[1]['Model']
max_mod_3 = max_modelos.iloc[2]['Model']
max_mod_4 = max_modelos.iloc[3]['Model']
max_mod_5 = max_modelos.iloc[4]['Model']

max_modelos
# Out:
#                              Model     frame  Adjusted R-Squared
# 0                    LGBMRegressor  models_1                0.82
# 40                    XGBRegressor  models_2                0.69
# 80   HistGradientBoostingRegressor  models_3                0.86
# 120                  LGBMRegressor  models_4                0.92
# 160  HistGradientBoostingRegressor  models_5                0.84

# %%
modelo_1=reg_1.models.get(max_mod_1 )
modelo_2=reg_2.models.get(max_mod_2 ) 
modelo_3=reg_3.models.get(max_mod_3 )
modelo_4=reg_4.models.get(max_mod_4 ) 
modelo_5=reg_5.models.get(max_mod_5 ) 

y_pred1 = cross_val_predict(modelo_1, X, y_1, cv=10)
y_pred2 = cross_val_predict(modelo_2, X, y_2, cv=10)
y_pred3 = cross_val_predict(modelo_3, X, y_3, cv=10)
y_pred4 = cross_val_predict(modelo_4, X, y_4, cv=10)
y_pred5 = cross_val_predict(modelo_5, X, y_5, cv=10)

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

_ = PredictionErrorDisplay.from_predictions(y_1, y_pred=y_pred1 , kind='actual_vs_predicted', ax=axs[0],  random_state=0, 
                                           scatter_kwargs={"alpha": 0.2, "color": "tab:blue"}, line_kwargs={"color": "tab:red"})
_ = PredictionErrorDisplay.from_predictions(y_1, y_pred=y_pred1 , kind='residual_vs_predicted', ax=axs[1],  random_state=0, 
                                           scatter_kwargs={"alpha": 0.2, "color": "tab:blue"}, line_kwargs={"color": "tab:red"})
axs[0].set_title(" Actual vs. Predicted values")
axs[1].set_title("Residuals vs. Predicted Values")

fig.suptitle(f"{max_mod_1} y={y_1.name}\nPlotting cross-validated predictions")
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
_ = PredictionErrorDisplay.from_predictions(y_2, y_pred=y_pred2 , kind='actual_vs_predicted', ax=axs[0],  random_state=0, 
                                           scatter_kwargs={"alpha": 0.2, "color": "tab:blue"}, line_kwargs={"color": "tab:red"})
_ = PredictionErrorDisplay.from_predictions(y_2, y_pred=y_pred2 , kind='residual_vs_predicted', ax=axs[1],  random_state=0,
                                           scatter_kwargs={"alpha": 0.2, "color": "tab:blue"}, line_kwargs={"color": "tab:red"})
axs[0].set_title("Actual vs. Predicted values")
axs[1].set_title("Residuals vs. Predicted Values")

fig.suptitle(f"{max_mod_2} y={y_2.name}\nPlotting cross-validated predictions")
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
_ = PredictionErrorDisplay.from_predictions(y_3, y_pred=y_pred3 , kind='actual_vs_predicted', ax=axs[0],  random_state=0, 
                                            scatter_kwargs={"alpha": 0.2, "color": "tab:blue"}, line_kwargs={"color": "tab:red"})
_ = PredictionErrorDisplay.from_predictions(y_3, y_pred=y_pred3 , kind='residual_vs_predicted', ax=axs[1],  random_state=0,
                                           scatter_kwargs={"alpha": 0.2, "color": "tab:blue"}, line_kwargs={"color": "tab:red"})
axs[0].set_title("Actual vs. Predicted values")
axs[1].set_title("Residuals vs. Predicted Values")

fig.suptitle(f"{max_mod_3} y={y_3.name}\nPlotting cross-validated predictions")
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
_ = PredictionErrorDisplay.from_predictions(y_4, y_pred=y_pred4 , kind='actual_vs_predicted', ax=axs[0],  random_state=0, 
                                            scatter_kwargs={"alpha": 0.2, "color": "tab:blue"}, line_kwargs={"color": "tab:red"})
_ = PredictionErrorDisplay.from_predictions(y_4, y_pred=y_pred4 , kind='residual_vs_predicted', ax=axs[1],  random_state=0,
                                           scatter_kwargs={"alpha": 0.2, "color": "tab:blue"}, line_kwargs={"color": "tab:red"})
axs[0].set_title("Actual vs. Predicted values")
axs[1].set_title("Residuals vs. Predicted Values")

fig.suptitle(f"{max_mod_4} y={y_4.name}\nPlotting cross-validated predictions")
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
_ = PredictionErrorDisplay.from_predictions(y_5, y_pred=y_pred5 , kind='actual_vs_predicted', ax=axs[0],  random_state=0, 
                                            scatter_kwargs={"alpha": 0.2, "color": "tab:blue"}, line_kwargs={"color": "tab:red"})
_ = PredictionErrorDisplay.from_predictions(y_5, y_pred=y_pred5 , kind='residual_vs_predicted', ax=axs[1],  random_state=0,
                                           scatter_kwargs={"alpha": 0.2, "color": "tab:blue"}, line_kwargs={"color": "tab:red"})
axs[0].set_title("Actual vs. Predicted values")
axs[1].set_title("Residuals vs. Predicted Values")

fig.suptitle(f"{max_mod_5} y={y_5.name}\nPlotting cross-validated predictions")
plt.tight_layout()
plt.show()

# %%
from sklearn.ensemble import HistGradientBoostingRegressor
#####################
X_train, X_test, y_train, y_test = train_test_split(X, y_4, test_size=0.3, random_state=42)

    
#reg_5 = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None, predictions=True , regressors=REGRESSORS)
regressor = HistGradientBoostingRegressor().fit(X_train, y_train)

#model_dictionary_melhor= reg_5.provide_models(X_train, X_test, y_train, y_test)
#_pred_melhor = cross_val_predict(regressor, X, y_4, cv=10)

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
viz1 = ResidualsPlot( regressor, hist=False, ax=axs[0])
viz1.fit(X_train, y_train)
viz1.score(X_test, y_test)
viz1.finalize()

viz2 = PredictionError(regressor,  ax=axs[1] )
viz2.fit(X_train,y_train)
viz2.score(X_test,y_test)
viz2.finalize()

axs[0].set_title("Actual vs. Predicted values")
axs[1].set_title("Residuals vs. Predicted Values")

fig.suptitle(f"{regressor} y={y_4.name}")
plt.tight_layout()
plt.show()

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

# Definindo os hiperparâmetros a serem ajustados
param_grid = {'learning_rate': [0.1, 0.01, 0.001],
              'max_iter': [100, 200, 300],
              'max_leaf_nodes': [15, 31, 65],
              'min_samples_leaf': [5, 10, 20]}

# Criando o modelo
hgbr = HistGradientBoostingRegressor()

# Criando o Grid Search
grid_search = GridSearchCV(estimator=hgbr, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')

# Ajustando o Grid Search aos dados
grid_search.fit(X_train, y_train)

# Exibindo os melhores hiperparâmetros encontrados
print(grid_search.best_params_)
# Out:
# {'learning_rate': 0.1, 'max_iter': 300, 'max_leaf_nodes': 31, 'min_samples_leaf': 10}

# %%
# Suponha que você tenha os valores reais y_test
y_pred = modelo_4.predict(X_test_4)
mae = mean_absolute_error(y_test_4, y_pred)
mse = mean_squared_error(y_test_4, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_4, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-squared:", r2)
# Out:
# MAE: 0.25690718752321734
# MSE: 0.1548747308418904
# RMSE: 0.3935412695536396
# R-squared: 0.9233950817849332

# %%
# Gráfico de dispersão com a linha horizontal para o MAE
plt.scatter(y_test_4, y_pred, alpha=0.7)
plt.plot([min(y_test_4), max(y_test_4)], [min(y_test_4), max(y_test_4)], color='red', linestyle='--', linewidth=2, label='Linha Diagonal')
plt.axhline(y=mae+min(y_test_4), color='green', linestyle='-', linewidth=2, label=f'MAE = {mae:.2f}')
plt.xlabel("Valores Reais")
plt.ylabel("Previsões")
plt.title("Gráfico de dispersão: Valores Reais vs. Previsões")
plt.legend()
plt.show()

# %%
from sklearn.inspection import permutation_importance
result = permutation_importance(modelo_4, X_test_4, y_test_4, n_repeats=10, random_state=42, n_jobs=2)

sorted_importances_idx = result.importances_mean.argsort()
importances = pd.DataFrame(
    result.importances[sorted_importances_idx].T,
    columns=X.columns[sorted_importances_idx],
)

ax = importances.plot.box(vert=False, whis=10, figsize=(10, 5))
#ax.set_title(f"{max_mod_3} y={y_3.name} \nPermutation Importances (test set)")
ax.axvline(x=0, color="k", linestyle="--")
ax.set_xlabel("Decrease in accuracy score")

ax.set_title(f"Figura __ - {max_mod_3} y={y_3.name} \nPermutation Importances (test set)", fontsize=12)

ax.figure.tight_layout()
plt.show()

# %%
from yellowbrick.regressor import residuals_plot
from yellowbrick.regressor import PredictionError
#from yellowbrick.regressor.alphas import alphas
#from yellowbrick.regressor import cooks_distance

#modelo=reg.models.get('HistGradientBoostingRegressor')

viz = residuals_plot(modelo_4, X_train_4, y_train_4, X_test_4, y_test_4, hist=False, qqplot=True)

# %%
from yellowbrick.regressor import PredictionError
visualizer = PredictionError(modelo_4)

visualizer.fit(X_train_4, y_train_4)  # Fit the training data to the visualizer
visualizer.score(X_test_4, y_test_4)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure
# Out:
# <Axes: title={'center': 'Prediction Error for LGBMRegressor'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
#model_OLS_1 = sm.OLS(y_1, X)
#model_OLS_2 = sm.OLS(y_2, X)
#model_OLS_3 = sm.OLS(y_3, X)
#model_OLS_4 = sm.OLS(y_4, X)
#model_OLS_5 = sm.OLS(y_5, X)

models = ['model_OLS_1', 'model_OLS_2', 'model_OLS_3', 'model_OLS_4', 'model_OLS_5' ]
y_s = [y_1, y_2, y_3, y_4, y_5]

# %%
from sklearn.model_selection import KFold
# Número de folds para o cross-validation
n_folds = 5

# Inicialize o objeto KFold
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
# Listas para armazenar as métricas de desempenho
#mse_scores = []
#mae_scores = []
#rsquared_scores = []
results_df = pd.DataFrame()

for modelo, y_atual in zip (models, y_s):
    modelo_nome=modelo
    #X_train, X_test, y_train, y_test = train_test_split(X, y_atual, test_size=0.25, random_state=42)

    exec("modelo = sm.OLS(y_atual, X)")
    # Obtenha as previsões para os dados de treinamento
    #y_train_pred = modelo.predict(X_train)
    
    # Listas para armazenar as métricas de desempenho
    mse_scores = []
    mae_scores = []
    rsquared_scores = []
    
    # Loop para realizar o cross-validation
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y_atual.iloc[train_index], y_atual.iloc[test_index]
        # Adicione uma constante ao conjunto de dados X_train e X_test (intercepto)
        #X_train = sm.add_constant(X_train)
        #X_test = sm.add_constant(X_test)
        
        # Crie o modelo OLS e ajuste-o aos dados de treinamento
        model = sm.OLS(y_train, X_train)
        results = model.fit()
        
        # Obtenha as previsões para os dados de teste
        y_pred = results.predict(X_test)
        
        # Calcule as métricas de avaliação do modelo
        mse = np.mean((y_test - y_pred) ** 2)
        mae = np.mean(np.abs(y_test - y_pred))
        rsquared = results.rsquared

    # Armazene as métricas para cada fold
    mse_scores.append(mse)
    mae_scores.append(mae)
    rsquared_scores.append(rsquared)
    
    # Calcule as médias das métricas de desempenho para todos os folds
    mean_mse = np.mean(mse_scores)
    mean_mae = np.mean(mae_scores)
    mean_rsquared = np.mean(rsquared_scores)

    # Crie um DataFrame com as métricas do modelo
    metrics_dict = {
        'Modelo': modelo_nome,
        'R-squared': mean_rsquared,
        'MSE': mean_mse,
        'MAE': mean_mae,
    }

    results_df = results_df.append(metrics_dict, ignore_index=True)

print(results_df)
# Out:
#         Modelo  R-squared              MSE       MAE
# 0  model_OLS_1       0.61 4258930137441.78 918331.81
# 1  model_OLS_2       0.62     661110621.54   1563.55
# 2  model_OLS_3       0.99             0.46      0.50
# 3  model_OLS_4       0.99             1.13      0.82
# 4  model_OLS_5       0.85             0.00      0.00

# %%
# Crie o modelo OLS e ajuste-o aos dados
modelo_OLS_4 = sm.OLS(y_4, X)
results = modelo_OLS_4.fit()

# Obtenha o resumo completo do modelo
summary = results.summary()

# Exiba o resumo
print(summary)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      log(Valor_Oferta)   R-squared (uncentered):                   0.993
# Model:                            OLS   Adj. R-squared (uncentered):              0.993
# Method:                 Least Squares   F-statistic:                          3.879e+04
# Date:                sáb, 29 jul 2023   Prob (F-statistic):                        0.00
# Time:                        08:40:48   Log-Likelihood:                         -14620.
# No. Observations:                9959   AIC:                                  2.931e+04
# Df Residuals:                    9924   BIC:                                  2.956e+04
# Df Model:                          35
# Covariance Type:            nonrobust
# =================================================================================================================================
#                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------
# vendido_em_grupo                                                 -0.6769      0.032    -20.904      0.000      -0.740      -0.613
# area                                                            6.66e-05   1.08e-05      6.191      0.000    4.55e-05    8.77e-05
# area_max                                                       5.122e-05    4.6e-06     11.147      0.000    4.22e-05    6.02e-05
# ra                                                               -0.0020      0.003     -0.622      0.534      -0.008       0.004
# setor                                                             0.0035      0.000     11.366      0.000       0.003       0.004
# max_condicao                                                      0.0016      0.000      5.377      0.000       0.001       0.002
# situacao                                                          0.0362      0.008      4.287      0.000       0.020       0.053
# tipologia                                                         0.0747      0.002     39.240      0.000       0.071       0.078
# destinacao                                                        0.0138      0.000     29.135      0.000       0.013       0.015
# ref_referencia                                                    0.4927      0.020     24.485      0.000       0.453       0.532
# pos_posicao                                                       0.0967      0.020      4.928      0.000       0.058       0.135
# ocupacao_valor                                                   -0.0168      0.001    -20.964      0.000      -0.018      -0.015
# medfrente                                                         0.0154      0.001     22.171      0.000       0.014       0.017
# vend_data_data                                                    0.0003   7.84e-06     43.526      0.000       0.000       0.000
# area_cons                                                      2.459e-07   3.33e-07      0.738      0.461   -4.08e-07    8.99e-07
# valor_coef_aproveitamento_area                                    0.3874      0.013     28.935      0.000       0.361       0.414
# index_atualizacao                                                -0.0013      0.000     -4.246      0.000      -0.002      -0.001
# espacos_comunitarios_contagem                                     0.0050      0.001      3.583      0.000       0.002       0.008
# distancia_de_600_metros_maisperto                                 0.0085      0.002      4.730      0.000       0.005       0.012
# distancia_de_600_metros_distancia                                -0.0005   3.36e-05    -14.103      0.000      -0.001      -0.000
# mobiliario_esporte_e_lazer_maisperto                              0.0002   6.59e-05      2.483      0.013    3.45e-05       0.000
# sistema_cicloviario_contagem                                      0.0076      0.001      9.021      0.000       0.006       0.009
# zoneamento_das_diretrizes_urbanisticas_maisperto                  0.0013      0.000      5.233      0.000       0.001       0.002
# linhas_de_transportes_de_alta_densidade_contagem                  0.0271      0.006      4.417      0.000       0.015       0.039
# pontes_viadutos_e_passarelas_maisperto                            0.0013   8.61e-05     14.771      0.000       0.001       0.001
# populacao_abrangida_pela_infraestrutura_cicloviaria_maisperto  9.962e-05   5.55e-05      1.794      0.073   -9.25e-06       0.000
# mapa_1c_unidades_de_planejamento_territorial_contagem             0.3571      0.032     11.119      0.000       0.294       0.420
# mapa_1c_unidades_de_planejamento_territorial_maisperto            0.2359      0.010     23.645      0.000       0.216       0.255
# area_tombada_contagem                                             1.1115      0.057     19.636      0.000       1.001       1.222
# regioes_administrativas_maisperto                                 0.0589      0.002     24.218      0.000       0.054       0.064
# rede_estrutural_de_transporte_coletivo_contagem                   0.0275      0.007      4.211      0.000       0.015       0.040
# intervencoes_cicloviarias_programa_nos_urbanos_contagem           0.0131      0.002      7.666      0.000       0.010       0.016
# regulaziracao_contagem                                            0.0369      0.017      2.197      0.028       0.004       0.070
# diretrizes_urbanisticas_contagem                                 -0.0591      0.017     -3.418      0.001      -0.093      -0.025
# rodovia_maisperto                                                 0.0013   7.98e-05     16.356      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                     1228.629   Durbin-Watson:                   1.239
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9316.305
# Skew:                          -0.343   Prob(JB):                         0.00
# Kurtosis:                       7.688   Cond. No.                     1.76e+05
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.76e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Adicione uma coluna constante para o termo do intercepto no modelo OLS
df['const'] = 1

# Etapa de backward elimination
# Escolha um nível de significância para decidir se uma variável deve ser removida ou não (por exemplo, 0.05)
significance_level = 0.05

while True:
    model = sm.OLS(y_5, X).fit()
    p_values = model.pvalues
    max_p_value = p_values.max()
    
    if max_p_value > significance_level:
        # Remove a variável com o maior valor p
        removed_variable = p_values.idxmax()
        X = X.drop(removed_variable, axis=1)
    else:
        # Todas as variáveis têm valores p menores ou iguais ao nível de significância
        break

print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      1/Valor_Oferta¹/²   R-squared (uncentered):                   0.853
# Model:                            OLS   Adj. R-squared (uncentered):              0.853
# Method:                 Least Squares   F-statistic:                              1804.
# Date:                sáb, 29 jul 2023   Prob (F-statistic):                        0.00
# Time:                        08:40:48   Log-Likelihood:                          52567.
# No. Observations:                9959   AIC:                                 -1.051e+05
# Df Residuals:                    9927   BIC:                                 -1.048e+05
# Df Model:                          32
# Covariance Type:            nonrobust
# =================================================================================================================================
#                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------
# vendido_em_grupo                                                  0.0010   3.79e-05     25.505      0.000       0.001       0.001
# area                                                           5.776e-08   1.26e-08      4.578      0.000     3.3e-08    8.25e-08
# area_max                                                       -5.01e-08   5.38e-09     -9.306      0.000   -6.06e-08   -3.95e-08
# ra                                                             3.624e-05   3.61e-06     10.040      0.000    2.92e-05    4.33e-05
# setor                                                          4.591e-06   3.37e-07     13.632      0.000    3.93e-06    5.25e-06
# max_condicao                                                  -8.141e-07   3.42e-07     -2.379      0.017   -1.48e-06   -1.43e-07
# situacao                                                       4.653e-05   9.89e-06      4.707      0.000    2.72e-05    6.59e-05
# tipologia                                                      6.776e-06   2.23e-06      3.043      0.002    2.41e-06    1.11e-05
# destinacao                                                     3.731e-06   5.53e-07      6.750      0.000    2.65e-06    4.81e-06
# ref_referencia                                                 -8.63e-05   2.35e-05     -3.676      0.000      -0.000   -4.03e-05
# pos_posicao                                                    4.833e-05    2.3e-05      2.104      0.035    3.31e-06    9.33e-05
# ocupacao_valor                                                 4.584e-05    9.4e-07     48.768      0.000     4.4e-05    4.77e-05
# medfrente                                                     -1.162e-05   8.16e-07    -14.233      0.000   -1.32e-05      -1e-05
# vend_data_data                                                 7.127e-08   8.93e-09      7.977      0.000    5.38e-08    8.88e-08
# valor_coef_aproveitamento_area                                   -0.0003   1.57e-05    -18.959      0.000      -0.000      -0.000
# index_atualizacao                                             -1.545e-05   3.59e-07    -43.002      0.000   -1.62e-05   -1.47e-05
# espacos_comunitarios_contagem                                 -6.961e-06   1.61e-06     -4.311      0.000   -1.01e-05    -3.8e-06
# distancia_de_600_metros_maisperto                             -1.402e-05   2.09e-06     -6.719      0.000   -1.81e-05   -9.93e-06
# distancia_de_600_metros_distancia                              3.212e-07   3.91e-08      8.207      0.000    2.44e-07    3.98e-07
# mobiliario_esporte_e_lazer_maisperto                          -4.458e-07    7.5e-08     -5.944      0.000   -5.93e-07   -2.99e-07
# sistema_cicloviario_contagem                                     3.3e-06   9.25e-07      3.569      0.000    1.49e-06    5.11e-06
# zoneamento_das_diretrizes_urbanisticas_maisperto              -2.451e-06    2.8e-07     -8.739      0.000      -3e-06    -1.9e-06
# linhas_de_transportes_de_alta_densidade_contagem              -2.134e-05   7.05e-06     -3.027      0.002   -3.52e-05   -7.52e-06
# pontes_viadutos_e_passarelas_maisperto                        -2.701e-07      1e-07     -2.697      0.007   -4.66e-07   -7.38e-08
# populacao_abrangida_pela_infraestrutura_cicloviaria_maisperto -4.265e-07   6.31e-08     -6.764      0.000    -5.5e-07   -3.03e-07
# mapa_1c_unidades_de_planejamento_territorial_contagem             0.0003   3.64e-05      7.065      0.000       0.000       0.000
# mapa_1c_unidades_de_planejamento_territorial_maisperto        -8.018e-05   1.03e-05     -7.780      0.000      -0.000      -6e-05
# area_tombada_contagem                                            -0.0014   6.62e-05    -21.081      0.000      -0.002      -0.001
# rede_estrutural_de_transporte_coletivo_contagem               -2.056e-05   7.43e-06     -2.768      0.006   -3.51e-05      -6e-06
# intervencoes_cicloviarias_programa_nos_urbanos_contagem           -9e-06      2e-06     -4.508      0.000   -1.29e-05   -5.09e-06
# diretrizes_urbanisticas_contagem                              -6.277e-05   1.81e-05     -3.464      0.001   -9.83e-05   -2.73e-05
# rodovia_maisperto                                              -6.34e-07    9.1e-08     -6.964      0.000   -8.12e-07   -4.56e-07
# ==============================================================================
# Omnibus:                     3669.170   Durbin-Watson:                   1.109
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            28487.552
# Skew:                           1.561   Prob(JB):                         0.00
# Kurtosis:                      10.675   Cond. No.                     8.80e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 8.8e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
model.resid
# Out:
# 0       0.00
# 1       0.00
# 2      -0.00
# 3       0.00
# 4      -0.00
# 5      -0.00
# 6       0.00
# 7       0.00
# 8      -0.00
# 9      -0.00
# 10      0.00
# 11     -0.00
# 12     -0.00
# 13      0.00
# 14      0.00
# 15      0.00
# 16      0.00
# 17      0.00
# 18      0.00
# 19      0.00
# 20      0.00
# 21     -0.00
# 22     -0.00
# 23     -0.00
# 24     -0.00
#         ...
# 9934    0.00
# 9935   -0.00
# 9936   -0.00
# 9937    0.00
# 9938   -0.00
# 9939   -0.00
# 9940   -0.00
# 9941   -0.00
# 9942   -0.00
# 9943   -0.00
# 9944   -0.00
# 9945   -0.00
# 9946   -0.00
# 9947   -0.00
# 9948   -0.00
# 9949    0.00
# 9950   -0.00
# 9951   -0.00
# 9952   -0.00
# 9953   -0.00
# 9954   -0.00
# 9955    0.00
# 9956    0.00
# 9957   -0.00
# 9958   -0.00
# Length: 9959, dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Supondo que você já tenha ajustado o modelo e tenha os resíduos disponíveis
# modelo_fit é o resultado do modelo ajustado

# Extrair os resíduos do modelo ajustado
residuos = model.resid

# Plotar a ACF e a PACF dos resíduos para detectar autocorrelação
plot_acf(residuos, lags=20)
plt.title("Autocorrelation Function (ACF) dos Resíduos")
plt.show()

plot_pacf(residuos, lags=20)
plt.title("Partial Autocorrelation Function (PACF) dos Resíduos")
plt.show()

# %%
model.bse
# Out:
# vendido_em_grupo                                                0.00
# area                                                            0.00
# area_max                                                        0.00
# ra                                                              0.00
# setor                                                           0.00
# max_condicao                                                    0.00
# situacao                                                        0.00
# tipologia                                                       0.00
# destinacao                                                      0.00
# ref_referencia                                                  0.00
# pos_posicao                                                     0.00
# ocupacao_valor                                                  0.00
# medfrente                                                       0.00
# vend_data_data                                                  0.00
# valor_coef_aproveitamento_area                                  0.00
# index_atualizacao                                               0.00
# espacos_comunitarios_contagem                                   0.00
# distancia_de_600_metros_maisperto                               0.00
# distancia_de_600_metros_distancia                               0.00
# mobiliario_esporte_e_lazer_maisperto                            0.00
# sistema_cicloviario_contagem                                    0.00
# zoneamento_das_diretrizes_urbanisticas_maisperto                0.00
# linhas_de_transportes_de_alta_densidade_contagem                0.00
# pontes_viadutos_e_passarelas_maisperto                          0.00
# populacao_abrangida_pela_infraestrutura_cicloviaria_maisperto   0.00
# mapa_1c_unidades_de_planejamento_territorial_contagem           0.00
# mapa_1c_unidades_de_planejamento_territorial_maisperto          0.00
# area_tombada_contagem                                           0.00
# rede_estrutural_de_transporte_coletivo_contagem                 0.00
# intervencoes_cicloviarias_programa_nos_urbanos_contagem         0.00
# diretrizes_urbanisticas_contagem                                0.00
# rodovia_maisperto                                               0.00
# dtype: float64

# %%
# variance of numeric features
(df
 .select_dtypes(include=np.number)
 .var()
 .astype('str'))
# Out:
# valor_oferta                                                     10484284057307.408
# area                                                             3721647.6659591785
# area_max                                                         20219606.121729992
# max_condicao                                                      1540.296719623362
# ocupacao_valor                                                   345.00675009850687
# medfrente                                                        346.28709875305424
# vend_data_data                                                    4782603.481426712
# area_cons                                                          1017240960.55587
# valor_coef_aproveitamento_area                                   1.4946790542998538
# espacos_comunitarios_contagem                                    116.47812335052527
# distancia_de_600_metros_maisperto                                107.85392636421092
# distancia_de_600_metros_distancia                                207645.18414237077
# mobiliario_esporte_e_lazer_maisperto                             37489.589714596266
# sistema_cicloviario_contagem                                     351.14307967749113
# zoneamento_das_diretrizes_urbanisticas_maisperto                 2613.7549159023374
# pontes_viadutos_e_passarelas_maisperto                           28957.226875620858
# populacao_abrangida_pela_infraestrutura_cicloviaria_maisperto     44786.25909278857
# intervencoes_cicloviarias_programa_nos_urbanos_contagem           142.0219049135801
# rodovia_maisperto                                                 29899.53687177076
# const                                                                           0.0
# dtype: object

# %%
# Calculate correlation matrix
corr_matrix = df.corr()

# Create a mask for correlations greater than 0.8
high_corr_mask = np.abs(corr_matrix) > 0.7

# Create a new correlation matrix where all correlations <= 0.8 are set to 0
high_corr_matrix = corr_matrix * high_corr_mask

sns.set(rc={'figure.figsize':(15,15)})
sns.heatmap(high_corr_matrix,
            annot=True,
            linewidths=.5,
            center=0,
            cbar=False,
            cmap="PiYG")
plt.show()

# %%
count=1
plt.subplots(figsize=(15,15))
for i in df.columns:
    if df[i].dtypes  not in ['object', 'string', 'category', 'datetime64[ns]', 'geometry']:
        plt.subplot(20,2,count)
        sns.boxplot(df[i], orient='h') #[0.05, 0.95]
        #ax.set_xlabel('Three separate samples')
        #ax.set_ylabel('Observed values')
        #plt.xlabel(f'{i}')
        plt.title(f'{i}')
        #plt.ylabel('Total Bill Amount ($)')
        count+=1
plt.tight_layout()
plt.show()

# %%
from yellowbrick.features import Rank2D

visualizer = Rank2D(algorithm="pearson")
visualizer.fit_transform(X)
visualizer.show()
# Out:
# <Axes: title={'center': 'Pearson Ranking of 32 Features'}>

# %% [markdown]
# # Fim do processamento [ x ]

# %%
import lightgbm as lgb
from skopt import BayesSearchCV

# Definir o espaço de busca para os hiperparâmetros
param_space = {
    'num_leaves': (2, 50),  # Intervalo para num_leaves
    'learning_rate': (0.01, 0.2),  # Intervalo para learning_rate
    'n_estimators': (50, 200),  # Intervalo para n_estimators
    'max_depth': (3, 15),  # Intervalo para max_depth
    'min_child_samples': (1, 20)  # Intervalo para min_child_samples
}

# Criar uma instância do LGBMRegressor
model = lgb.LGBMRegressor()

# Criar uma instância do BayesSearchCV
opt = BayesSearchCV(
    model,
    param_space,
    n_iter=50,  # Número de iterações de busca
    cv=3,  # Número de folds para validação cruzada
    n_jobs=-1,  # Número de núcleos do processador a serem usados (-1 usa todos disponíveis)
    random_state=42
)

# Realizar a busca bayesiana para encontrar os melhores hiperparâmetros
opt.fit(X, y_3)

# Exibir os melhores hiperparâmetros encontrados
print("Melhores hiperparâmetros:")
print(opt.best_params_)
# Out:
# Melhores hiperparâmetros:
# OrderedDict([('learning_rate', 0.2), ('max_depth', 3), ('min_child_samples', 20), ('n_estimators', 200), ('num_leaves', 50)])

# %%
#from sklearn.linear_model import Lasso
#from yellowbrick.regressor import prediction_error
##from sklearn.svm import SVC
#from yellowbrick.model_selection import ValidationCurve
#from sklearn.model_selection import StratifiedKFold
#from sklearn.tree import DecisionTreeRegressor
#from lightgbm import LGBMRegressor
## Create the train and test data
#X_train, X_test, y_train, y_test = train_test_split(X, y_3, test_size=0.2, random_state=42)

## Instantiate the linear model and visualizer
#model = LGBMRegressor()
#visualizer = prediction_error(model, X_train, y_train, X_test, y_test)

# %%
#from yellowbrick.regressor import ResidualsPlot
#from sklearn.linear_model import LinearRegression
#from sklearn.model_selection import train_test_split
#rom sklearn.ensemble._hist_gradient_boosting.gradient_boosting  import HistGradientBoostingRegressor

#regressor_atual = HistGradientBoostingRegressor

## Create training and test sets
#X_train, X_test, y_train, y_test = train_test_split(
#    X, y_3, test_size=0.1
#)

#visualizer = ResidualsPlot(regressor_atual())
#visualizer.fit(X_train, y_train)
#visualizer.score(X_test, y_test)
#visualizer.show()

# %%
df.describe(include='all').round(2).T
# Out:
#                                                      count unique  \
# vendido_em_grupo                                   9959.00   2.00
# valor_oferta                                       9959.00    NaN
# area                                               9959.00    NaN
# area_max                                           9959.00    NaN
# ra                                                    9959     19
# setor                                                 9959    164
# max_condicao                                       9959.00    NaN
# situacao                                              9959      8
# tipologia                                             9959     40
# destinacao                                            9959    192
# ref_referencia                                     9959.00   3.00
# pos_posicao                                        9959.00   3.00
# ocupacao_valor                                     9959.00    NaN
# medfrente                                          9959.00    NaN
# vend_data_data                                     9959.00    NaN
# area_cons                                          9959.00    NaN
# valor_coef_aproveitamento_area                     9959.00    NaN
# index_atualizacao                                     9959    237
# espacos_comunitarios_contagem                      9959.00    NaN
# distancia_de_600_metros_maisperto                  9959.00    NaN
# distancia_de_600_metros_distancia                  9959.00    NaN
# mobiliario_esporte_e_lazer_maisperto               9959.00    NaN
# sistema_cicloviario_contagem                       9959.00    NaN
# zoneamento_das_diretrizes_urbanisticas_maisperto   9959.00    NaN
# linhas_de_transportes_de_alta_densidade_contagem   9959.00  13.00
# pontes_viadutos_e_passarelas_maisperto             9959.00    NaN
# populacao_abrangida_pela_infraestrutura_ciclovi... 9959.00    NaN
# mapa_1c_unidades_de_planejamento_territorial_co... 9959.00   4.00
# mapa_1c_unidades_de_planejamento_territorial_ma... 9959.00   6.00
# area_tombada_contagem                              9959.00   2.00
# regioes_administrativas_maisperto                  9959.00  23.00
# rede_estrutural_de_transporte_coletivo_contagem    9959.00  20.00
# intervencoes_cicloviarias_programa_nos_urbanos_... 9959.00    NaN
# regulaziracao_contagem                             9959.00   5.00
# diretrizes_urbanisticas_contagem                   9959.00   7.00
# rodovia_maisperto                                  9959.00    NaN
# const                                              9959.00    NaN
#
#                                                                                                   top  \
# vendido_em_grupo                                                                                 0.00
# valor_oferta                                                                                      NaN
# area                                                                                              NaN
# area_max                                                                                          NaN
# ra                                                                                          Samambaia
# setor                                                                        QS-SAMAMBAIA (SAMAMBAIA)
# max_condicao                                                                                      NaN
# situacao                                                                                     1 - VAGO
# tipologia                                                                                       60217
# destinacao                                          60217 - UOS CSIIR 2 - COMERCIAL, PRESTA€ÇO DE ...
# ref_referencia                                                                                   3.00
# pos_posicao                                                                                      2.00
# ocupacao_valor                                                                                    NaN
# medfrente                                                                                         NaN
# vend_data_data                                                                                    NaN
# area_cons                                                                                         NaN
# valor_coef_aproveitamento_area                                                                    NaN
# index_atualizacao                                                                          2003-02-01
# espacos_comunitarios_contagem                                                                     NaN
# distancia_de_600_metros_maisperto                                                                 NaN
# distancia_de_600_metros_distancia                                                                 NaN
# mobiliario_esporte_e_lazer_maisperto                                                              NaN
# sistema_cicloviario_contagem                                                                      NaN
# zoneamento_das_diretrizes_urbanisticas_maisperto                                                  NaN
# linhas_de_transportes_de_alta_densidade_contagem                                                 0.00
# pontes_viadutos_e_passarelas_maisperto                                                            NaN
# populacao_abrangida_pela_infraestrutura_ciclovi...                                                NaN
# mapa_1c_unidades_de_planejamento_territorial_co...                                               1.00
# mapa_1c_unidades_de_planejamento_territorial_ma...                                               1.00
# area_tombada_contagem                                                                            0.00
# regioes_administrativas_maisperto                                                                5.00
# rede_estrutural_de_transporte_coletivo_contagem                                                  1.00
# intervencoes_cicloviarias_programa_nos_urbanos_...                                                NaN
# regulaziracao_contagem                                                                           0.00
# diretrizes_urbanisticas_contagem                                                                 2.00
# rodovia_maisperto                                                                                 NaN
# const                                                                                             NaN
#
#                                                       freq      mean  \
# vendido_em_grupo                                   8541.00       NaN
# valor_oferta                                           NaN 916170.68
# area                                                   NaN    716.89
# area_max                                               NaN   1779.72
# ra                                                    2987       NaN
# setor                                                 1284       NaN
# max_condicao                                           NaN     43.78
# situacao                                              6475       NaN
# tipologia                                             1970       NaN
# destinacao                                            1970       NaN
# ref_referencia                                     8740.00       NaN
# pos_posicao                                        6198.00       NaN
# ocupacao_valor                                         NaN     86.13
# medfrente                                              NaN     15.53
# vend_data_data                                         NaN  15808.64
# area_cons                                              NaN   1728.58
# valor_coef_aproveitamento_area                         NaN      2.65
# index_atualizacao                                      205       NaN
# espacos_comunitarios_contagem                          NaN     22.58
# distancia_de_600_metros_maisperto                      NaN      9.47
# distancia_de_600_metros_distancia                      NaN    354.50
# mobiliario_esporte_e_lazer_maisperto                   NaN    114.56
# sistema_cicloviario_contagem                           NaN     20.16
# zoneamento_das_diretrizes_urbanisticas_maisperto       NaN     40.91
# linhas_de_transportes_de_alta_densidade_contagem   2941.00       NaN
# pontes_viadutos_e_passarelas_maisperto                 NaN    121.79
# populacao_abrangida_pela_infraestrutura_ciclovi...     NaN    108.87
# mapa_1c_unidades_de_planejamento_territorial_co... 6694.00       NaN
# mapa_1c_unidades_de_planejamento_territorial_ma... 3659.00       NaN
# area_tombada_contagem                              8954.00       NaN
# regioes_administrativas_maisperto                  2360.00       NaN
# rede_estrutural_de_transporte_coletivo_contagem    2160.00       NaN
# intervencoes_cicloviarias_programa_nos_urbanos_...     NaN      8.62
# regulaziracao_contagem                             4357.00       NaN
# diretrizes_urbanisticas_contagem                   3946.00       NaN
# rodovia_maisperto                                      NaN    204.15
# const                                                  NaN      1.00
#
#                                                           std     min  \
# vendido_em_grupo                                          NaN     NaN
# valor_oferta                                       3237944.42 3375.00
# area                                                  1929.16    4.00
# area_max                                              4496.62    4.00
# ra                                                        NaN     NaN
# setor                                                     NaN     NaN
# max_condicao                                            39.25    4.00
# situacao                                                  NaN     NaN
# tipologia                                                 NaN     NaN
# destinacao                                                NaN     NaN
# ref_referencia                                            NaN     NaN
# pos_posicao                                               NaN     NaN
# ocupacao_valor                                          18.57    0.00
# medfrente                                               18.61    0.00
# vend_data_data                                        2186.92 3470.00
# area_cons                                            31894.22    4.00
# valor_coef_aproveitamento_area                           1.22    0.00
# index_atualizacao                                         NaN     NaN
# espacos_comunitarios_contagem                           10.79    0.00
# distancia_de_600_metros_maisperto                       10.39    0.00
# distancia_de_600_metros_distancia                      455.68    0.00
# mobiliario_esporte_e_lazer_maisperto                   193.62    0.00
# sistema_cicloviario_contagem                            18.74    0.00
# zoneamento_das_diretrizes_urbanisticas_maisperto        51.12    0.00
# linhas_de_transportes_de_alta_densidade_contagem          NaN     NaN
# pontes_viadutos_e_passarelas_maisperto                 170.17    0.00
# populacao_abrangida_pela_infraestrutura_ciclovi...     211.63    0.00
# mapa_1c_unidades_de_planejamento_territorial_co...        NaN     NaN
# mapa_1c_unidades_de_planejamento_territorial_ma...        NaN     NaN
# area_tombada_contagem                                     NaN     NaN
# regioes_administrativas_maisperto                         NaN     NaN
# rede_estrutural_de_transporte_coletivo_contagem           NaN     NaN
# intervencoes_cicloviarias_programa_nos_urbanos_...      11.92    0.00
# regulaziracao_contagem                                    NaN     NaN
# diretrizes_urbanisticas_contagem                          NaN     NaN
# rodovia_maisperto                                      172.91    0.00
# const                                                    0.00    1.00
#
#                                                         25%       50%  \
# vendido_em_grupo                                        NaN       NaN
# valor_oferta                                       79601.00 176670.00
# area                                                 128.20    300.00
# area_max                                             315.00    640.00
# ra                                                      NaN       NaN
# setor                                                   NaN       NaN
# max_condicao                                          17.00     33.00
# situacao                                                NaN       NaN
# tipologia                                               NaN       NaN
# destinacao                                              NaN       NaN
# ref_referencia                                          NaN       NaN
# pos_posicao                                             NaN       NaN
# ocupacao_valor                                        70.00    100.00
# medfrente                                              7.00     10.00
# vend_data_data                                     14161.00  15993.00
# area_cons                                            250.00    562.80
# valor_coef_aproveitamento_area                         2.00      2.50
# index_atualizacao                                       NaN       NaN
# espacos_comunitarios_contagem                         15.00     21.00
# distancia_de_600_metros_maisperto                      0.00      6.00
# distancia_de_600_metros_distancia                      0.00      0.00
# mobiliario_esporte_e_lazer_maisperto                  23.00     58.00
# sistema_cicloviario_contagem                           8.00     15.00
# zoneamento_das_diretrizes_urbanisticas_maisperto       0.00     25.00
# linhas_de_transportes_de_alta_densidade_contagem        NaN       NaN
# pontes_viadutos_e_passarelas_maisperto                 0.00     25.00
# populacao_abrangida_pela_infraestrutura_ciclovi...    11.00     72.00
# mapa_1c_unidades_de_planejamento_territorial_co...      NaN       NaN
# mapa_1c_unidades_de_planejamento_territorial_ma...      NaN       NaN
# area_tombada_contagem                                   NaN       NaN
# regioes_administrativas_maisperto                       NaN       NaN
# rede_estrutural_de_transporte_coletivo_contagem         NaN       NaN
# intervencoes_cicloviarias_programa_nos_urbanos_...     0.00      0.00
# regulaziracao_contagem                                  NaN       NaN
# diretrizes_urbanisticas_contagem                        NaN       NaN
# rodovia_maisperto                                     96.00    143.00
# const                                                  1.00      1.00
#
#                                                          75%          max
# vendido_em_grupo                                         NaN          NaN
# valor_oferta                                       405058.50 129670000.00
# area                                                  822.00     75471.50
# area_max                                             1469.43    181131.60
# ra                                                       NaN          NaN
# setor                                                    NaN          NaN
# max_condicao                                           55.00       403.00
# situacao                                                 NaN          NaN
# tipologia                                                NaN          NaN
# destinacao                                               NaN          NaN
# ref_referencia                                           NaN          NaN
# pos_posicao                                              NaN          NaN
# ocupacao_valor                                        100.00       100.00
# medfrente                                              20.00       500.00
# vend_data_data                                      17637.00     19662.00
# area_cons                                            1400.00   3163500.00
# valor_coef_aproveitamento_area                          3.00        22.11
# index_atualizacao                                        NaN          NaN
# espacos_comunitarios_contagem                          29.00        74.00
# distancia_de_600_metros_maisperto                      22.00        41.00
# distancia_de_600_metros_distancia                     697.50      1500.00
# mobiliario_esporte_e_lazer_maisperto                  128.00      2442.00
# sistema_cicloviario_contagem                           26.00       103.00
# zoneamento_das_diretrizes_urbanisticas_maisperto       54.00       192.00
# linhas_de_transportes_de_alta_densidade_contagem         NaN          NaN
# pontes_viadutos_e_passarelas_maisperto                166.00       733.00
# populacao_abrangida_pela_infraestrutura_ciclovi...    199.00      4071.00
# mapa_1c_unidades_de_planejamento_territorial_co...       NaN          NaN
# mapa_1c_unidades_de_planejamento_territorial_ma...       NaN          NaN
# area_tombada_contagem                                    NaN          NaN
# regioes_administrativas_maisperto                        NaN          NaN
# rede_estrutural_de_transporte_coletivo_contagem          NaN          NaN
# intervencoes_cicloviarias_programa_nos_urbanos_...     16.00        57.00
# regulaziracao_contagem                                   NaN          NaN
# diretrizes_urbanisticas_contagem                         NaN          NaN
# rodovia_maisperto                                     312.00       497.00
# const                                                   1.00         1.00

# %%
df['valor_oferta'].unique()
# Out:
# 7863660991.808835
